# %%
import pandas as pd
import re

# %%
df = pd.read_csv('C:/Users/HIMANSHU/Desktop/Data Analyst Bootcamp/Assignments/PROJECT PORTFOLIO/NY Housing Market/NY-House-Dataset.csv')
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4801 non-null   object
#  1   TYPE                         4801 non-null   object
#  2   PRICE                        4801 non-null   int64
#  3   BEDS                         4801 non-null   int64
#  4   BATH                         4801 non-null   float64
#  5   PROPERTYSQFT                 4801 non-null   float64
#  6   ADDRESS                      4801 non-null   object
#  7   STATE                        4801 non-null   object
#  8   MAIN_ADDRESS                 4801 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  10  LOCALITY                     4801 non-null   object
#  11  SUBLOCALITY                  4801 non-null   object
#  12  STREET_NAME                  4801 non-null   object
# ...

# %%
df['BROKERTITLE'] = df['BROKERTITLE'].str.replace('Brokered by ', '')
df['BROKERTITLE'] = df['BROKERTITLE'].str.encode('ascii', 'ignore').str.decode('ascii')
df.tail(10)
# Out:
#                             BROKERTITLE                        TYPE    PRICE  \
# 4791                 Corcoran East Side              Co-op for sale   370000
# 4792                   Ilite Realty Inc  Multi-family home for sale  1700000
# 4793                          Engel & V              Co-op for sale  1950000
# 4794               Brown Harris Stevens              Condo for sale   945000
# 4795                        RE MAX Edge  Multi-family home for sale  2999999
# 4796                            COMPASS              Co-op for sale   599000
# 4797                Mjr Real Estate Llc              Co-op for sale   245000
# 4798  Douglas Elliman - 575 Madison Ave              Co-op for sale  1275000
# 4799        E Realty International Corp              Condo for sale   598125
# 4800             Nyc Realty Brokers Llc              Co-op for sale   349000
#
#       BEDS  BATH  PROPERTYSQFT                                   ADDRESS  \
# ...

# %%
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0                    Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                            Serhant      Condo for sale
# 2                                         Sowae Corp      House for sale
# 3                                            COMPASS      Condo for sale
# 4  Sotheby's International Realty - East Side Man...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %%
df['BATH'] = df['BATH'].astype(int)
df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0                    Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                            Serhant      Condo for sale
# 2                                         Sowae Corp      House for sale
# 3                                            COMPASS      Condo for sale
# 4  Sotheby's International Realty - East Side Man...  Townhouse for sale
#
#        PRICE  BEDS  BATH  PROPERTYSQFT  \
# 0     315000     2     2        1400.0
# 1  195000000     7    10       17545.0
# 2     260000     4     2        2015.0
# 3      69000     3     1         445.0
# 4   55000000     7     2       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %%
zip_code_mapping = {
    '11214': 'Bensonhurst, Brooklyn',
    '10301': 'St. George, Staten Island',
    '10309': 'Charleston, Staten Island',
    '10303': 'Mariners Harbor, Staten Island',
    '11234': 'Marine Park, Brooklyn',
    '11414': 'Howard Beach, Queens',
    '10310': 'Westerleigh, Staten Island',
    '10003': 'Greenwich Village, Manhattan',
    '11417': 'Ozone Park, Queens',
    '10304': 'Stapleton, Staten Island',
    '10463': 'Kingsbridge, Bronx',
    '11214': 'Bensonhurst, Brooklyn',  # Repeated zip code, please verify
    '10017': 'Midtown East, Manhattan',
    '10306': 'Oakwood, Staten Island',
    '10471': 'Riverdale, Bronx',
    '10312': 'Annadale, Staten Island',
    '11412': 'Jamaica, Queens',
    '10465': 'Throgs Neck, Bronx',
    '10471': 'Riverdale, Bronx',
    '10002': 'Lower East Side, Manhattan',
    '10466': 'Wakefield, Bronx',
    '11237': 'Bushwick, Brooklyn',
    '11218': 'Kensington, Brooklyn',
}

df['ADMINISTRATIVE_AREA_LEVEL_2'] = df['ADMINISTRATIVE_AREA_LEVEL_2'].replace(zip_code_mapping)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4801 non-null   object
#  1   TYPE                         4801 non-null   object
#  2   PRICE                        4801 non-null   int64
#  3   BEDS                         4801 non-null   int64
#  4   BATH                         4801 non-null   int32
#  5   PROPERTYSQFT                 4801 non-null   float64
#  6   ADDRESS                      4801 non-null   object
#  7   STATE                        4801 non-null   object
#  8   MAIN_ADDRESS                 4801 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  10  LOCALITY                     4801 non-null   object
#  11  SUBLOCALITY                  4801 non-null   object
#  12  STREET_NAME                  4801 non-null   object
# ...

# %%
df.to_csv('C:/Users/HIMANSHU/Desktop/Data Analyst Bootcamp/Assignments/PROJECT PORTFOLIO/NY Housing Market/Cleaned_Data.csv', index=False)
